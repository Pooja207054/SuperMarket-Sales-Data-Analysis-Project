# %% [markdown]
# # Step-1 : Business Problem Understanding

# %% [markdown]
# **This dataset provides a comprehensive overview of supermarket sales,
# offering insights into consumer purchasing behaviors, product trends, and retail dynamics.
# Analyzing this data enables retailers, marketers, and analysts to optimize strategies,
# improve inventory management, and enhance customer experiences. Explore sales volumes,
# seasonal patterns, and promotional impacts for informed decision-making in the competitive retail sector.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Step-2 : Data Understanding

# %% [markdown]
# **Invoice ID: A unique identifier for each invoice or transaction.**
#
# **Branch: The branch or location where the transaction occurred.**
#
# **City: The city where the branch is located.**
#
# **Customer Type: Indicates whether the customer is a regular or new customer.**
#
# **Gender: The gender of the customer.**
#
# **Product Line: The category or type of product purchased.**
#
# **Unit Price: The price of a single unit of the product.**
#
# **Quantity: The number of units of the product purchased.**
#
# **Tax 5%: The amount of tax (5% of the total cost) applied to the transaction.**
#
# **Total: The total cost of the transaction, including tax.**
#
# **Date: The date when the transaction took place.**
#
# **Time: The time of day when the transaction occurred.**
#
# **Payment: The payment method used (e.g., credit card, cash).**
#
# **COGS (Cost of Goods Sold): The direct costs associated with producing or purchasing the products sold.**
#
# **Gross Margin Percentage: The profit margin percentage for the transaction.**
#
# **Gross Income: The total profit earned from the transaction.**
#
# **Rating: Customer satisfaction rating or feedback on the transaction.**

# %% [markdown]
# **load data & undrstand every variable**

# %%
df=pd.read_csv("C:\\Users\\Pooja\\Downloads\\supermarket_sales.csv")
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
df["Invoice ID"].nunique()
# Out:
# 1000

# %% [markdown]
# **Drop unimportant columns as per the feature selection**

# %%
df.drop(columns=["Invoice ID"],inplace=True)

# %%
df["Branch"].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df["Branch"].value_counts()
# Out:
# Branch
# A    340
# B    332
# C    328
# Name: count, dtype: int64

# %%
df["City"].unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
df["City"].value_counts()
# Out:
# City
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: count, dtype: int64

# %%
df["Customer type"].unique()
# Out:
# array(['Member', 'Normal'], dtype=object)

# %%
df["Customer type"].value_counts()
# Out:
# Customer type
# Member    501
# Normal    499
# Name: count, dtype: int64

# %%
df["Gender"].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Female    501
# Male      499
# Name: count, dtype: int64

# %%
df["Product line"].unique()
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %%
df["Product line"].value_counts()
# Out:
# Product line
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: count, dtype: int64

# %%
df["Unit price"].unique()
# Out:
# array([74.69, 15.28, 46.33, 58.22, 86.31, 85.39, 68.84, 73.56, 36.26,
#        54.84, 14.48, 25.51, 46.95, 43.19, 71.38, 93.72, 68.93, 72.61,
#        54.67, 40.3 , 86.04, 87.98, 33.2 , 34.56, 88.63, 52.59, 33.52,
#        87.67, 88.36, 24.89, 94.13, 78.07, 83.78, 96.58, 99.42, 68.12,
#        62.62, 60.88, 54.92, 30.12, 86.72, 56.11, 69.12, 98.7 , 15.37,
#        93.96, 56.69, 20.01, 18.93, 82.63, 91.4 , 44.59, 17.87, 15.43,
#        16.16, 85.98, 44.34, 89.6 , 72.35, 30.61, 24.74, 55.73, 55.07,
#        15.81, 75.74, 15.87, 33.47, 97.61, 78.77, 18.33, 89.48, 62.12,
#        48.52, 75.91, 74.67, 41.65, 49.04, 78.31, 20.38, 99.19, 96.68,
#        19.25, 80.36, 48.91, 83.06, 76.52, 49.38, 42.47, 76.99, 47.38,
#        44.86, 21.98, 64.36, 89.75, 97.16, 87.87, 12.45, 52.75, 82.7 ,
#        48.71, 78.55, 23.07, 58.26, 30.35, 88.67, 27.38, 62.13, 33.98,
#        81.97, 16.49, 98.21, 72.84, 58.07, 80.79, 27.02, 21.94, 51.36,
# ...

# %%
df["Unit price"].value_counts()
# Out:
# Unit price
# 83.77    3
# 39.62    2
# 24.74    2
# 19.15    2
# 73.47    2
#         ..
# 57.95    1
# 47.65    1
# 42.82    1
# 48.09    1
# 88.34    1
# Name: count, Length: 943, dtype: int64

# %%
df["Quantity"].unique()
# Out:
# array([ 7,  5,  8,  6, 10,  2,  3,  4,  1,  9], dtype=int64)

# %%
df["Quantity"].value_counts()
# Out:
# Quantity
# 10    119
# 1     112
# 4     109
# 7     102
# 5     102
# 6      98
# 9      92
# 2      91
# 3      90
# 8      85
# Name: count, dtype: int64

# %%
df["Tax 5%"].unique()
# Out:
# array([26.1415,  3.82  , 16.2155, 23.288 , 30.2085, 29.8865, 20.652 ,
#        36.78  ,  3.626 ,  8.226 ,  2.896 ,  5.102 , 11.7375, 21.595 ,
#        35.69  , 28.116 , 24.1255, 21.783 ,  8.2005,  4.03  , 21.51  ,
#        13.197 ,  3.32  ,  8.64  , 13.2945, 21.036 ,  1.676 ,  8.767 ,
#        22.09  , 11.2005, 23.5325, 35.1315, 33.512 ,  9.658 , 19.884 ,
#         3.406 , 15.655 , 27.396 , 21.968 , 12.048 ,  4.336 ,  5.611 ,
#        20.736 , 39.48  ,  1.537 , 18.792 , 25.5105,  9.0045,  5.679 ,
#        41.315 , 31.99  , 11.1475,  3.574 ,  0.7715,  1.616 , 34.392 ,
#         4.434 , 35.84  , 36.175 ,  9.183 ,  3.711 , 16.719 , 24.7815,
#         7.905 , 15.148 ,  7.935 ,  3.347 , 29.283 , 39.385 ,  0.9165,
#        44.74  , 31.06  ,  7.278 , 22.773 , 33.6015, 20.825 , 22.068 ,
#        39.155 ,  5.095 , 29.757 , 14.502 ,  7.7   , 16.072 , 12.2275,
#        29.071 , 19.13  , 17.283 ,  2.1235, 23.097 ,  9.476 , 22.43  ,
# ...

# %%
df["Tax 5%"].value_counts()
# Out:
# Tax 5%
# 10.3260    2
# 4.4640     2
# 4.1540     2
# 9.0045     2
# 22.4280    2
#           ..
# 7.2135     1
# 19.5895    1
# 26.9150    1
# 24.2575    1
# 30.9190    1
# Name: count, Length: 990, dtype: int64

# %%
df["Total"].unique()
# Out:
# array([ 548.9715,   80.22  ,  340.5255,  489.048 ,  634.3785,  627.6165,
#         433.692 ,  772.38  ,   76.146 ,  172.746 ,   60.816 ,  107.142 ,
#         246.4875,  453.495 ,  749.49  ,  590.436 ,  506.6355,  457.443 ,
#         172.2105,   84.63  ,  451.71  ,  277.137 ,   69.72  ,  181.44  ,
#         279.1845,  441.756 ,   35.196 ,  184.107 ,  463.89  ,  235.2105,
#         494.1825,  737.7615,  703.752 ,  202.818 ,  417.564 ,   71.526 ,
#         328.755 ,  575.316 ,  461.328 ,  253.008 ,   91.056 ,  117.831 ,
#         435.456 ,  829.08  ,   32.277 ,  394.632 ,  535.7205,  189.0945,
#         119.259 ,  867.615 ,  671.79  ,  234.0975,   75.054 ,   16.2015,
#          33.936 ,  722.232 ,   93.114 ,  752.64  ,  759.675 ,  192.843 ,
#          77.931 ,  351.099 ,  520.4115,  166.005 ,  318.108 ,  166.635 ,
#          70.287 ,  614.943 ,  827.085 ,   19.2465,  939.54  ,  652.26  ,
#         152.838 ,  478.233 ,  705.6315,  437.325 ,  463.428 ,  822.255 ,
# ...

# %%
df["Total"].describe()
# Out:
# count    1000.000000
# mean      322.966749
# std       245.885335
# min        10.678500
# 25%       124.422375
# 50%       253.848000
# 75%       471.350250
# max      1042.650000
# Name: Total, dtype: float64

# %%
df["Date"].unique()
# Out:
# array(['1/5/2019', '3/8/2019', '3/3/2019', '1/27/2019', '2/8/2019',
#        '3/25/2019', '2/25/2019', '2/24/2019', '1/10/2019', '2/20/2019',
#        '2/6/2019', '3/9/2019', '2/12/2019', '2/7/2019', '3/29/2019',
#        '1/15/2019', '3/11/2019', '1/1/2019', '1/21/2019', '3/5/2019',
#        '3/15/2019', '2/17/2019', '3/2/2019', '3/22/2019', '3/10/2019',
#        '1/25/2019', '1/28/2019', '1/7/2019', '3/23/2019', '1/17/2019',
#        '2/2/2019', '3/4/2019', '3/16/2019', '2/27/2019', '2/10/2019',
#        '3/19/2019', '2/3/2019', '3/7/2019', '2/28/2019', '3/27/2019',
#        '1/20/2019', '3/12/2019', '2/15/2019', '3/6/2019', '2/14/2019',
#        '3/13/2019', '1/24/2019', '1/6/2019', '2/11/2019', '1/22/2019',
#        '1/13/2019', '1/9/2019', '1/12/2019', '1/26/2019', '1/23/2019',
#        '2/23/2019', '1/2/2019', '2/9/2019', '3/26/2019', '3/1/2019',
#        '2/1/2019', '3/28/2019', '3/24/2019', '2/5/2019', '1/19/2019',
# ...

# %%
df["Date"].value_counts()
# Out:
# Date
# 2/7/2019     20
# 2/15/2019    19
# 3/14/2019    18
# 3/2/2019     18
# 1/8/2019     18
#              ..
# 1/4/2019      6
# 2/28/2019     6
# 2/21/2019     6
# 3/17/2019     6
# 2/1/2019      6
# Name: count, Length: 89, dtype: int64

# %%
df["Time"].unique()
# Out:
# array(['13:08', '10:29', '13:23', '20:33', '10:37', '18:30', '14:36',
#        '11:38', '17:15', '13:27', '18:07', '17:03', '10:25', '16:48',
#        '19:21', '16:19', '11:03', '10:39', '18:00', '15:30', '11:24',
#        '10:40', '12:20', '11:15', '17:36', '19:20', '15:31', '12:17',
#        '19:48', '15:36', '19:39', '12:43', '14:49', '10:12', '10:42',
#        '12:28', '19:15', '17:17', '13:24', '13:01', '18:45', '10:11',
#        '13:03', '20:39', '19:47', '17:24', '15:47', '12:45', '17:08',
#        '10:19', '15:10', '14:42', '15:46', '11:49', '19:01', '11:26',
#        '11:28', '15:55', '20:36', '17:47', '10:55', '13:40', '12:27',
#        '14:35', '16:40', '15:43', '15:01', '10:04', '18:50', '12:46',
#        '18:17', '18:21', '17:04', '14:20', '15:48', '16:24', '18:56',
#        '19:56', '18:37', '10:17', '14:31', '10:23', '20:35', '16:57',
#        '17:55', '19:54', '16:42', '12:09', '20:05', '20:38', '13:11',
# ...

# %%
df["Time"].value_counts()
# Out:
# Time
# 19:48    7
# 14:42    7
# 17:38    6
# 17:16    5
# 11:40    5
#         ..
# 13:26    1
# 11:17    1
# 14:57    1
# 17:53    1
# 19:12    1
# Name: count, Length: 506, dtype: int64

# %%
df.drop(columns=["Time"],inplace=True)

# %%
df["Payment"].unique()
# Out:
# array(['Ewallet', 'Cash', 'Credit card'], dtype=object)

# %%
df["Payment"].value_counts()
# Out:
# Payment
# Ewallet        345
# Cash           344
# Credit card    311
# Name: count, dtype: int64

# %%
df["cogs"].unique()
# Out:
# array([522.83,  76.4 , 324.31, 465.76, 604.17, 597.73, 413.04, 735.6 ,
#         72.52, 164.52,  57.92, 102.04, 234.75, 431.9 , 713.8 , 562.32,
#        482.51, 435.66, 164.01,  80.6 , 430.2 , 263.94,  66.4 , 172.8 ,
#        265.89, 420.72,  33.52, 175.34, 441.8 , 224.01, 470.65, 702.63,
#        670.24, 193.16, 397.68,  68.12, 313.1 , 547.92, 439.36, 240.96,
#         86.72, 112.22, 414.72, 789.6 ,  30.74, 375.84, 510.21, 180.09,
#        113.58, 826.3 , 639.8 , 222.95,  71.48,  15.43,  32.32, 687.84,
#         88.68, 716.8 , 723.5 , 183.66,  74.22, 334.38, 495.63, 158.1 ,
#        302.96, 158.7 ,  66.94, 585.66, 787.7 ,  18.33, 894.8 , 621.2 ,
#        145.56, 455.46, 672.03, 416.5 , 441.36, 783.1 , 101.9 , 595.14,
#        290.04, 154.  , 321.44, 244.55, 581.42, 382.6 , 345.66,  42.47,
#        461.94, 189.52, 448.6 , 153.86, 579.24,  89.75,  97.16, 878.7 ,
#         74.7 , 158.25, 496.2 ,  48.71, 706.95, 207.63, 349.56, 212.45,
# ...

# %%
df["cogs"].value_counts()
# Out:
# cogs
# 206.52    2
# 89.28     2
# 83.08     2
# 180.09    2
# 448.56    2
#          ..
# 144.27    1
# 391.79    1
# 538.30    1
# 485.15    1
# 618.38    1
# Name: count, Length: 990, dtype: int64

# %%
df["gross margin percentage"].unique()
# Out:
# array([4.76190476])

# %%
df["gross margin percentage"].value_counts()
# Out:
# gross margin percentage
# 4.761905    1000
# Name: count, dtype: int64

# %%
df["gross income"].unique()
# Out:
# array([26.1415,  3.82  , 16.2155, 23.288 , 30.2085, 29.8865, 20.652 ,
#        36.78  ,  3.626 ,  8.226 ,  2.896 ,  5.102 , 11.7375, 21.595 ,
#        35.69  , 28.116 , 24.1255, 21.783 ,  8.2005,  4.03  , 21.51  ,
#        13.197 ,  3.32  ,  8.64  , 13.2945, 21.036 ,  1.676 ,  8.767 ,
#        22.09  , 11.2005, 23.5325, 35.1315, 33.512 ,  9.658 , 19.884 ,
#         3.406 , 15.655 , 27.396 , 21.968 , 12.048 ,  4.336 ,  5.611 ,
#        20.736 , 39.48  ,  1.537 , 18.792 , 25.5105,  9.0045,  5.679 ,
#        41.315 , 31.99  , 11.1475,  3.574 ,  0.7715,  1.616 , 34.392 ,
#         4.434 , 35.84  , 36.175 ,  9.183 ,  3.711 , 16.719 , 24.7815,
#         7.905 , 15.148 ,  7.935 ,  3.347 , 29.283 , 39.385 ,  0.9165,
#        44.74  , 31.06  ,  7.278 , 22.773 , 33.6015, 20.825 , 22.068 ,
#        39.155 ,  5.095 , 29.757 , 14.502 ,  7.7   , 16.072 , 12.2275,
#        29.071 , 19.13  , 17.283 ,  2.1235, 23.097 ,  9.476 , 22.43  ,
# ...

# %%
df["gross income"].value_counts()
# Out:
# gross income
# 10.3260    2
# 4.4640     2
# 4.1540     2
# 9.0045     2
# 22.4280    2
#           ..
# 7.2135     1
# 19.5895    1
# 26.9150    1
# 24.2575    1
# 30.9190    1
# Name: count, Length: 990, dtype: int64

# %%
continous=["Unit price","Tax 5%","Total","cogs","gross income","Rating"]
discrete_categorical=["Branch","City","Gender","Product line","Payment"]
discrete_count=["Quantity"]

# %%
df.dtypes
# Out:
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %% [markdown]
# **Exploratory Data Analysis**
#
#
# **for continous variables**

# %%
df[continous].describe()
# Out:
#         Unit price       Tax 5%        Total        cogs  gross income  \
# count  1000.000000  1000.000000  1000.000000  1000.00000   1000.000000
# mean     55.672130    15.379369   322.966749   307.58738     15.379369
# std      26.494628    11.708825   245.885335   234.17651     11.708825
# min      10.080000     0.508500    10.678500    10.17000      0.508500
# 25%      32.875000     5.924875   124.422375   118.49750      5.924875
# 50%      55.230000    12.088000   253.848000   241.76000     12.088000
# 75%      77.935000    22.445250   471.350250   448.90500     22.445250
# max      99.960000    49.650000  1042.650000   993.00000     49.650000
#
#            Rating
# count  1000.00000
# mean      6.97270
# std       1.71858
# min       4.00000
# 25%       5.50000
# 50%       7.00000
# 75%       8.50000
# max      10.00000

# %%
plt.rcParams["figure.figsize"] = (18, 12)

# Create a 3x2 grid for subplots (3 rows, 2 columns)
fig, axes = plt.subplots(3, 2)

# Flatten the axes for easier access
axes = axes.flatten()

# Plot histograms with KDE for each column
sns.histplot(df["Tax 5%"], kde=True, ax=axes[0])
axes[0].set_title('Tax 5%')

sns.histplot(df["Total"], kde=True, ax=axes[1])
axes[1].set_title('Total')

sns.histplot(df["cogs"], kde=True, ax=axes[2])
axes[2].set_title('COGS')

sns.histplot(df["gross income"], kde=True, ax=axes[3])
axes[3].set_title('Gross Income')

sns.histplot(df["Rating"], kde=True, ax=axes[4])
axes[4].set_title('Rating')

sns.histplot(df["Unit price"], kde=True, ax=axes[5])
axes[5].set_title('Unit Price')

# Adjust the layout to prevent overlap
plt.tight_layout()

# Show the plots
plt.show()

# %%
df[continous].skew()
# Out:
# Unit price      0.007077
# Tax 5%          0.892570
# Total           0.892570
# cogs            0.892570
# gross income    0.892570
# Rating          0.009010
# dtype: float64

# %%
sns.heatmap(df[continous].corr(),annot=True)
plt.show()

# %%
sns.pairplot(df[continous])
plt.show()

# %%
df[discrete_categorical].describe()
# Out:
#        Branch    City  Gender         Product line  Payment
# count    1000    1000    1000                 1000     1000
# unique      3       3       2                    6        3
# top         A  Yangon  Female  Fashion accessories  Ewallet
# freq      340     340     501                  178      345

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 10))  # Adjust the figure size for better visualization

# Create a 2x3 grid of subplots
plt.subplot(2, 3, 1)
sns.boxplot(df["Unit price"])
plt.title("Unit price")

plt.subplot(2, 3, 2)
sns.boxplot(df["Tax 5%"])
plt.title("Tax 5%")

plt.subplot(2, 3, 3)
sns.boxplot(df["Total"])
plt.title("Total")

plt.subplot(2, 3, 4)
sns.boxplot(df["cogs"])
plt.title("COGS")

plt.subplot(2, 3, 5)
sns.boxplot(df["gross income"])
plt.title("Gross Income")

plt.subplot(2, 3, 6)
sns.boxplot(df["Rating"])
plt.title("Rating")

plt.suptitle("Outliers in the Data", fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust layout and leave space for the title
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming df is your DataFrame and contains the necessary categorical columns
# Load your DataFrame (example)
# df = pd.read_csv('your_data_file.csv')

# Check and clean column names
df.columns = df.columns.str.strip()  # Remove leading/trailing spaces
print("DataFrame Columns:", df.columns.tolist())  # Print column names for verification

# Set figure size
plt.rcParams["figure.figsize"] = (18, 8)

# Create a subplot for each categorical column
plt.subplot(2, 3, 1)  # Position for the first plot
sns.countplot(x="Branch", data=df)
plt.title("Count of Branches")  # Title for the first plot

plt.subplot(2, 3, 2)  # Position for the second plot
sns.countplot(x="City", data=df)
plt.title("Count of Cities")  # Title for the second plot

plt.subplot(2, 3, 3)  # Position for the third plot
sns.countplot(x="Gender", data=df)
plt.title("Count of Gender")  # Title for the third plot

plt.subplot(2, 3, 4)  # Position for the fourth plot
sns.countplot(x="Product line", data=df)  # Make sure this name is correct
plt.title("Count of Product Line")  # Title for the fourth plot

plt.subplot(2, 3, 5)  # Position for the fifth plot
sns.countplot(x="Payment", data=df)
plt.title("Count of Payment Methods")  # Title for the fifth plot

# Add a super title for all plots
plt.suptitle("Univariate Analysis on Categorical Columns")

# Display the plots
plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # Adjust layout to make room for the super title
plt.show()
# Out:
# DataFrame Columns: ['Branch', 'City', 'Customer type', 'Gender', 'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date', 'Payment', 'cogs', 'gross margin percentage', 'gross income', 'Rating']

# %%
df.isnull().sum()
# Out:
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# **check skweness**

# %%
df[continous].skew()
# Out:
# Unit price      0.007077
# Tax 5%          0.892570
# Total           0.892570
# cogs            0.892570
# gross income    0.892570
# Rating          0.009010
# dtype: float64

# %%
df.columns
# Out:
# Index(['Branch', 'City', 'Customer type', 'Gender', 'Product line',
#        'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date', 'Payment', 'cogs',
#        'gross margin percentage', 'gross income', 'Rating'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **check outliers**

# %% [markdown]
# **Data preprocessing**

# %% [markdown]
# **there is no need to data preprocessing**

# %%
df
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date      Payment    cogs  \
# ...

# %%
df.to_excel("cleaned_data_Super_market _sales.xlsx",index=False)
